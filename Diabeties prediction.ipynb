# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/diabetes.csv")
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# # New Section

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
X = df.drop(['Outcome'], axis =1)
y=df["Outcome"]
print(X)
#y = df['Outcome']
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
from lazypredict.Supervised import LazyClassifier
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=.5,random_state =123)

clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
models,predictions = clf.fit(X_train, X_test, y_train, y_test)

print(models)

# %%
# !pip install lazypredict

# %%
from sklearn.model_selection import train_test_split
X_train, X_test,y_train, y_test= train_test_split(X, y, test_size= 1/3, random_state=99)

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn import set_config
set_config(display="diagram")

# %%
pipe=Pipeline([('scalar',StandardScaler()),('KNeighbor',KNeighborsClassifier(n_neighbors=3))])
pipe.fit(X_train,y_train).score(X_test,y_test)
pipe.set_params().fit(X_train,y_train).score(X_test,y_test)
# Out:
# 0.75390625

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
reg = LinearRegression().fit(x_train, y_train)
reg.score(x_train, y_train)

# %%
from sklearn.datasets import load_diabetes
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeRegressor
reg = DecisionTreeRegressor(random_state=0)
cross_val_score(reg, x_train, y_train, cv=10)

# %%
reg.fit(x_train,y_train)

# %%
reg.score(x_train,y_train)

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(max_depth=2, random_state=0)
clf.fit(X_train, y_train)

# %%
y_pred = clf.predict(X_test)
clf.score(X_test,y_pred)

# %%
import pickle
pickle.dump(clf, open('Diabetes_check_model.pkl','wb'))

# %%
model = pickle.load(open("Diabetes_check_model.pkl",'rb'))

# %%
Pregnancies = input("Pregnancies")
Glucose = input("Glucose")
BloodPressure = input("BloodPressure")
Insulin = input("Insulin")
SkinThickness = input("SkinThickness")
BMI = input("BMI")
DiabetesPedigreeFunction = input("DiabetesPedigreeFunction")
Age = input("Age")
features_dict = {
    'Pregnancies': Pregnancies,
    'Glucose': Glucose,
    'BloodPressure': BloodPressure,
    'SkinThickness': SkinThickness,
    'Insulin': Insulin,
    'BMI': BMI,
    'DiabetesPedigreeFunction': DiabetesPedigreeFunction,
    'Age': Age,
}
features = features_dict
features_df = pd.DataFrame([features])
Predicted = model.predict(features_df)
print(Predicted)
if int(Predicted) == 0:
  print("you dont have diabeties")
else:
  print("you have diabeties")

# %%
int(Predicted)
